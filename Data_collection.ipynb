# %% [markdown]
# # **Data collection using Python**
# ![Screenshot 2024-06-24 234301.png](data:image/png;base64,...)

# %% [markdown]
# ## **Simple**

# %%
pip install yfinance --upgrade --no-cache-dir

# %%
import yfinance as yf
bac = yf.Ticker("BAC")
print(bac.info)
# Out:
# {'address1': 'Bank of America Corporate Center', 'address2': '100 North Tryon Street', 'city': 'Charlotte', 'state': 'NC', 'zip': '28255', 'country': 'United States', 'phone': '704 386 5681', 'website': 'https://www.bankofamerica.com', 'industry': 'Banks - Diversified', 'industryKey': 'banks-diversified', 'industryDisp': 'Banks - Diversified', 'sector': 'Financial Services', 'sectorKey': 'financial-services', 'sectorDisp': 'Financial Services', 'longBusinessSummary': 'Bank of America Corporation, through its subsidiaries, provides banking and financial products and services for individual consumers, small and middle-market businesses, institutional investors, large corporations, and governments worldwide. It operates in four segments: Consumer Banking, Global Wealth & Investment Management (GWIM), Global Banking, and Global Markets. The Consumer Banking segment offers traditional and money market savings accounts, certificates of deposit and IRAs, non-interest and interest-bearing ch
# ...

# %%
bac.history(period="max")
# Out:
#                                 Open       High        Low      Close  \
# Date
# 1973-02-21 00:00:00-05:00   1.561252   1.561252   1.561252   1.561252
# 1973-02-22 00:00:00-05:00   1.566526   1.566526   1.566526   1.566526
# 1973-02-23 00:00:00-05:00   1.561252   1.561252   1.561252   1.561252
# 1973-02-26 00:00:00-05:00   1.561252   1.561252   1.561252   1.561252
# 1973-02-27 00:00:00-05:00   1.561252   1.561252   1.561252   1.561252
# ...                              ...        ...        ...        ...
# 2024-06-17 00:00:00-04:00  39.090000  39.529999  38.980000  39.509998
# 2024-06-18 00:00:00-04:00  39.560001  40.020000  39.459999  39.990002
# 2024-06-20 00:00:00-04:00  39.779999  40.310001  39.750000  39.990002
# 2024-06-21 00:00:00-04:00  39.849998  39.910000  39.369999  39.490002
# 2024-06-24 00:00:00-04:00  39.770000  40.340000  39.650002  40.145000
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %% [markdown]
# ## **Medium**

# %%
import requests

# %%
headers = {
    'sec-ch-ua': '"Not/A)Brand";v="8", "Chromium";v="126", "Google Chrome";v="126"',
    'Referer': 'https://finance.yahoo.com/quote/BAC/?guccounter=1&guce_referrer=aHR0cHM6Ly93d3cuZ29vZ2xlLmNvbS8&guce_referrer_sig=AQAAALC0ib-AqDw1gIPuzHYU4GiEntq5R9Z3cRUofj5_d4ty6BqKXwtcZ7s2si0MUe8mshJAU_ORWKHxeQyh6AgJ5XAIZrk7iAyVQer8OxZk6hkBZ7uHC7ytDheJLOCOpqKjgcE01ZcyfICn00hG8zttbXL2wHIZIaNYqXShDgbGCC0Y',
    'sec-ch-ua-mobile': '?0',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36',
    'sec-ch-ua-platform': '"Windows"',
}

response = requests.get(
    'https://query2.finance.yahoo.com/v8/finance/chart/BAC?period1=1718925600&period2=1719250200&interval=5m&includePrePost=true&events=div%7Csplit%7Cearn&&lang=en-US&region=US',
    headers=headers,
)

# %%
print(response.content)
# Out:
# b'{"chart":{"result":[{"meta":{"currency":"USD","symbol":"BAC","exchangeName":"NYQ","fullExchangeName":"NYSE","instrumentType":"EQUITY","firstTradeDate":99153000,"regularMarketTime":1719259201,"hasPrePostMarketData":true,"gmtoffset":-14400,"timezone":"EDT","exchangeTimezoneName":"America/New_York","regularMarketPrice":40.02,"fiftyTwoWeekHigh":40.34,"fiftyTwoWeekLow":39.65,"regularMarketDayHigh":40.34,"regularMarketDayLow":39.65,"regularMarketVolume":28842288,"chartPreviousClose":39.99,"previousClose":39.49,"scale":3,"priceHint":2,"currentTradingPeriod":{"pre":{"timezone":"EDT","end":1719322200,"start":1719302400,"gmtoffset":-14400},"regular":{"timezone":"EDT","end":1719345600,"start":1719322200,"gmtoffset":-14400},"post":{"timezone":"EDT","end":1719360000,"start":1719345600,"gmtoffset":-14400}},"tradingPeriods":{"pre":[[{"timezone":"EDT","end":1718890200,"start":1718870400,"gmtoffset":-14400}],[{"timezone":"EDT","end":1718976600,"start":1718956800,"gmtoffset":-14400}],[{"timezone":"E
# ...

# %% [markdown]
# # **Web scraping**

# %%
pip install beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup

def get_table_data():
    # Send a request to the YouTube homepage
    url = "https://ticker.finology.in/"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    }
    response = requests.get(url, headers=headers)

    # Check if the request was successful
    if response.status_code != 200:
        raise Exception(f"Failed to load page: {response.status_code}")

    #print(response.content)
    # Parse the response content
    soup = BeautifulSoup(response.content, 'html.parser')
    table = soup.find("table",class_ ="table table-sm table-hover screenertable")

    print(table)
    headers =table.find_all("th")
    all_rows =table.find_all("tr")
    for x in headers:
      column = x.text
      print(column)

    for y in all_rows[1:]:
      td = y.find_all("td")
      row = [ tr.text for tr in td]
      print(row)
    #print(table)
    return table

# %%
# Print the extracted video titles and links
table_data = get_table_data()
# Out:
# <table class="table table-sm table-hover screenertable">
# <thead>
# <tr>
# <th scope="col">Company</th>
# <th scope="col">Price<span class="muted">Rs.</span></th>
# <th scope="col">Day High<span class="muted">Rs.</span></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>
# <a class="complink" href="company/SCRIP-100008">Amara Raja Energy</a>
# </td>
# <td class="Number">1622.40</td>
# <td class="Number">1656.05</td>
# </tr>
# <tr>
# <td>
# <a class="complink" href="company/GRSE">Garden Reach Ship</a>
# </td>
# <td class="Number">1986.00</td>
# <td class="Number">1998.00</td>
# </tr>
# <tr>
# <td>
# <a class="complink" href="company/EXIDEIND">Exide Inds</a>
# </td>
# <td class="Number">589.25</td>
# <td class="Number">620.35</td>
# </tr>
# <tr>
# <td>
# <a class="complink" href="company/ICICIBANK">ICICI Bank</a>
# </td>
# <td class="Number">1196.10</td>
# <td class="Number">1199.70</td>
# </tr>
# <tr>
# <td>
# <a class="complink" href="company/AXISBANK">Axis Bank</a>
# </td>
# ...
